# %%
# Resumo dos principais insights
print("📌 Conclusões:")
print("- Produtividade máxima ocorre com chuva adequada, temperatura moderada e radiação elevada.")
print("- Excesso de calor (>34°C) e excesso de chuva reduzem eficiência.")
print("- Umidade média influencia mais a produção total do que a produtividade por hectare.")
print("- Risco financeiro em anos ruins pode ser significativo.")
print("- Modelos de classificação mostraram que padrões climáticos podem antecipar anos de baixa produtividade.")
