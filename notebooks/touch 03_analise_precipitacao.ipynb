# %%
# Anos mais chuvosos
top3_chuvosos = (dados_limpos.groupby('Ano')['Chuva_acumulada_(mm)']
                 .sum().sort_values(ascending=False).head(3))
display(top3_chuvosos)

# Relação chuva x produtividade
correlacao_chuva = dados_limpos['Chuva_acumulada_(mm)'].corr(dados_limpos['Produtividade_(t/ha)'])
print(f"Correlação chuva x produtividade: {correlacao_chuva:.2f}")
